# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("202108_202308_주민등록인구및세대현황_월간.csv", encoding="cp949")
print(data.columns)
print(data.index)
print(data)

# 연도별 행정구역별 거주자 인구
print("연도별 행정구역별 거주자 인구")
print(data.iloc[1, 0])
print(data.iloc[1, range(1, len(data.columns), 6)]) #1번 컬럼부터 전체 컬럼까지 6개씩 건너뛰기 -> 총 인구수만 출력되도록 함

# 연도별 세대당 인구
print(data.iloc[14, 0])
print(data.iloc[14, range(3, len(data.columns), 6)])

rowIndex = data.query('행정구역.str.contains("가야제1동")').index.values[0]
print(data.iloc[rowIndex, range(3,len(data.columns), 6)])
# Out:
# Index(['행정구역', '2021년08월_총인구수', '2021년08월_세대수', '2021년08월_세대당 인구',
#        '2021년08월_남자 인구수', '2021년08월_여자 인구수', '2021년08월_남여 비율', '2021년09월_총인구수',
#        '2021년09월_세대수', '2021년09월_세대당 인구',
#        ...
#        '2023년07월_세대당 인구', '2023년07월_남자 인구수', '2023년07월_여자 인구수',
#        '2023년07월_남여 비율', '2023년08월_총인구수', '2023년08월_세대수', '2023년08월_세대당 인구',
#        '2023년08월_남자 인구수', '2023년08월_여자 인구수', '2023년08월_남여 비율'],
#       dtype='object', length=151)
# RangeIndex(start=0, stop=21, step=1)
#                              행정구역 2021년08월_총인구수 2021년08월_세대수  2021년08월_세대당 인구  \
# 0   부산광역시 부산광역시 부산진구 (2623000000)       355,138      173,084             2.05
# 1    부산광역시 부산진구 부전제1동(2623051000)        15,942       10,219             1.56
# 2    부산광역시 부산진구 부전제2동(2623052000)         9,872        5,522             1.79
# 3      부산광역시 부산진구 연지동(2623054000)        20,707        8,709             2.38
# 4      부산광역시 부산진구 초읍동(2623055000)        22,165       10,030             2.21
# 5    부산광역시 부산진구 양정제1동(2623056000)        20,215        9,231             2.19
# 6    부산광역시 부산진구 양정제2동(2623057000)        12,216        7,602             1.61
# 7    부산광역시 부산진구 전포제1동(2623060000)        21,989       12,135             1.81
# 8    부산광역시 부산진구 전포제2동(2623061000)        20,898       11,426             1.83
# 9    부산광역시 부산진구 부암제1동(2623064000)        22,912        9,711             2.36
# 10   부산광역시 부산진구 부암제3동(2623066000)        17,660        7,000             2.52
# 11   부산광역시 부산진구 당감제1동(2623067000)        23,229       10,359             2.24
# 12   부산광역시 부산진구 당감제2동(2623068000)        10,339        4,661             2.22
# 13   부산광역시 부산진구 당감제4동(2623070000)        11,375        5,140             2.21
# 14   부산광역시 부산진구 가야제1동(2623071000)        19,290       10,089             1.91
# 15   부산광역시 부산진구 가야제2동(2623072000)        16,906        7,320             2.31
# 16   부산광역시 부산진구 개금제1동(2623074000)        16,829        8,869             1.90
# 17   부산광역시 부산진구 개금제2동(2623075000)        11,120        5,030             2.21
# 18   부산광역시 부산진구 개금제3동(2623076000)        28,970       12,462             2.32
# 19   부산광역시 부산진구 범천제1동(2623077000)        12,019        7,213             1.67
# 20   부산광역시 부산진구 범천제2동(2623078000)        20,485       10,356             1.98
#
#    2021년08월_남자 인구수 2021년08월_여자 인구수  2021년08월_남여 비율 2021년09월_총인구수 2021년09월_세대수  \
# 0          171,257         183,881            0.93       354,924      173,279
# 1            7,994           7,948            1.01        15,960       10,244
# 2            4,904           4,968            0.99         9,897        5,550
# 3            9,776          10,931            0.89        20,664        8,687
# 4           10,698          11,467            0.93        22,203       10,056
# 5            9,528          10,687            0.89        20,214        9,249
# 6            5,575           6,641            0.84        12,136        7,608
# 7           10,537          11,452            0.92        21,899       12,084
# 8            9,821          11,077            0.89        20,953       11,479
# 9           11,235          11,677            0.96        22,958        9,766
# 10           8,679           8,981            0.97        17,605        6,987
# 11          11,100          12,129            0.92        23,178       10,369
# 12           4,927           5,412            0.91        10,320        4,657
# 13           5,564           5,811            0.96        11,366        5,131
# 14           9,650           9,640            1.00        19,309       10,137
# 15           8,188           8,718            0.94        16,904        7,326
# 16           8,068           8,761            0.92        16,826        8,892
# 17           5,437           5,683            0.96        11,081        5,020
# 18          13,976          14,994            0.93        28,943       12,467
# 19           5,679           6,340            0.90        12,043        7,209
# 20           9,921          10,564            0.94        20,465       10,361
#
#     2021년09월_세대당 인구  ... 2023년07월_세대당 인구 2023년07월_남자 인구수  2023년07월_여자 인구수  \
# 0              2.05  ...            1.98         171,650          185,646
# 1              1.56  ...            1.49           7,914            8,013
# 2              1.78  ...            1.60           5,416            5,563
# 3              2.38  ...            2.39          12,242           13,413
# 4              2.21  ...            2.12          10,043           10,860
# 5              2.19  ...            2.08           8,949           10,194
# 6              1.60  ...            1.52           5,337            6,304
# 7              1.81  ...            1.74          10,116           10,977
# 8              1.83  ...            1.82          10,914           12,445
# 9              2.35  ...            2.23          11,396           12,124
# 10             2.52  ...            2.45           8,141            8,511
# 11             2.24  ...            2.15          10,353           11,358
# 12             2.22  ...            2.15           4,698            5,232
# 13             2.22  ...            2.14           5,217            5,584
# 14             1.90  ...            1.83           8,995            8,906
# 15             2.31  ...            2.27           8,853            9,431
# 16             1.89  ...            1.87           8,851            9,439
# 17             2.21  ...            2.10           4,969            5,325
# 18             2.32  ...            2.22          13,061           14,180
# 19             1.67  ...            1.62           5,740            6,620
# 20             1.98  ...            1.94          10,445           11,167
#
#    2023년07월_남여 비율 2023년08월_총인구수  2023년08월_세대수 2023년08월_세대당 인구 2023년08월_남자 인구수  \
# 0            0.92       357,196       180,664            1.98         171,587
# 1            0.99        15,941        10,757            1.48           7,904
# 2            0.97        11,021         6,868            1.60           5,440
# 3            0.91        25,745        10,749            2.40          12,270
# 4            0.92        20,833         9,815            2.12          10,015
# 5            0.88        19,227         9,271            2.07           8,979
# 6            0.85        11,654         7,648            1.52           5,345
# 7            0.92        21,078        12,100            1.74          10,106
# 8            0.88        23,402        12,888            1.82          10,951
# 9            0.94        23,553        10,557            2.23          11,420
# 10           0.96        16,633         6,777            2.45           8,134
# 11           0.91        21,684        10,098            2.15          10,334
# 12           0.90         9,896         4,606            2.15           4,682
# 13           0.93        10,760         5,035            2.14           5,194
# 14           1.01        17,717         9,722            1.82           8,915
# 15           0.94        18,306         8,067            2.27           8,858
# 16           0.94        18,361         9,814            1.87           8,896
# 17           0.93        10,267         4,895            2.10           4,951
# 18           0.92        27,189        12,240            2.22          13,040
# 19           0.87        12,339         7,611            1.62           5,734
# 20           0.94        21,590        11,146            1.94          10,419
#
#     2023년08월_여자 인구수 2023년08월_남여 비율
# 0           185,609           0.92
# 1             8,037           0.98
# 2             5,581           0.97
# 3            13,475           0.91
# 4            10,818           0.93
# 5            10,248           0.88
# 6             6,309           0.85
# 7            10,972           0.92
# 8            12,451           0.88
# 9            12,133           0.94
# 10            8,499           0.96
# 11           11,350           0.91
# 12            5,214           0.90
# 13            5,566           0.93
# 14            8,802           1.01
# 15            9,448           0.94
# 16            9,465           0.94
# 17            5,316           0.93
# 18           14,149           0.92
# 19            6,605           0.87
# 20           11,171           0.93
#
# [21 rows x 151 columns]
# 연도별 행정구역별 거주자 인구
# 부산광역시 부산진구 부전제1동(2623051000)
# 2021년08월_총인구수    15,942
# 2021년09월_총인구수    15,960
# 2021년10월_총인구수    15,944
# 2021년11월_총인구수    15,923
# 2021년12월_총인구수    15,902
# 2022년01월_총인구수    15,925
# 2022년02월_총인구수    15,894
# 2022년03월_총인구수    15,844
# 2022년04월_총인구수    15,817
# 2022년05월_총인구수    15,772
# 2022년06월_총인구수    15,785
# 2022년07월_총인구수    15,785
# 2022년08월_총인구수    15,823
# 2022년09월_총인구수    15,809
# 2022년10월_총인구수    15,778
# 2022년11월_총인구수    15,756
# 2022년12월_총인구수    15,768
# 2023년01월_총인구수    15,808
# 2023년02월_총인구수    15,880
# 2023년03월_총인구수    15,873
# 2023년04월_총인구수    15,890
# 2023년05월_총인구수    15,926
# 2023년06월_총인구수    15,926
# 2023년07월_총인구수    15,927
# 2023년08월_총인구수    15,941
# Name: 1, dtype: object
# 부산광역시 부산진구 가야제1동(2623071000)
# 2021년08월_세대당 인구    1.91
# 2021년09월_세대당 인구     1.9
# 2021년10월_세대당 인구     1.9
# 2021년11월_세대당 인구     1.9
# 2021년12월_세대당 인구    1.89
# 2022년01월_세대당 인구    1.89
# 2022년02월_세대당 인구    1.89
# 2022년03월_세대당 인구    1.88
# 2022년04월_세대당 인구    1.88
# 2022년05월_세대당 인구    1.88
# 2022년06월_세대당 인구    1.87
# 2022년07월_세대당 인구    1.87
# 2022년08월_세대당 인구    1.86
# 2022년09월_세대당 인구    1.86
# 2022년10월_세대당 인구    1.85
# 2022년11월_세대당 인구    1.85
# 2022년12월_세대당 인구    1.85
# 2023년01월_세대당 인구    1.85
# 2023년02월_세대당 인구    1.85
# 2023년03월_세대당 인구    1.84
# 2023년04월_세대당 인구    1.83
# 2023년05월_세대당 인구    1.83
# 2023년06월_세대당 인구    1.83
# 2023년07월_세대당 인구    1.83
# 2023년08월_세대당 인구    1.82
# Name: 14, dtype: object
# 2021년08월_세대당 인구    1.91
# 2021년09월_세대당 인구     1.9
# 2021년10월_세대당 인구     1.9
# 2021년11월_세대당 인구     1.9
# 2021년12월_세대당 인구    1.89
# 2022년01월_세대당 인구    1.89
# 2022년02월_세대당 인구    1.89
# 2022년03월_세대당 인구    1.88
# 2022년04월_세대당 인구    1.88
# 2022년05월_세대당 인구    1.88
# 2022년06월_세대당 인구    1.87
# 2022년07월_세대당 인구    1.87
# 2022년08월_세대당 인구    1.86
# 2022년09월_세대당 인구    1.86
# 2022년10월_세대당 인구    1.85
# 2022년11월_세대당 인구    1.85
# 2022년12월_세대당 인구    1.85
# 2023년01월_세대당 인구    1.85
# 2023년02월_세대당 인구    1.85
# 2023년03월_세대당 인구    1.84
# 2023년04월_세대당 인구    1.83
# 2023년05월_세대당 인구    1.83
# 2023년06월_세대당 인구    1.83
# 2023년07월_세대당 인구    1.83
# 2023년08월_세대당 인구    1.82
# Name: 14, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("202108_202308_주민등록인구및세대현황_월간.csv", encoding="cp949")
dataDict = {}
for i in range(1, len(data)):
    dataDict[data.iloc[i,0]] = data.iloc[1, range(i, len(data.columns), 6)]

# print(dataDict)

name = input("행정구역을 입력하세요: ")

findData = None
for i,j in dataDict.items():
    if name in i:
        findData = dataDict.get(i)

# pd.DataFrame(findData)

figure = plt.figure()
axes = figure.add_subplot(111)

# axes.pie(findData, findData.index.values)
axes.plot(findData)
plt.show()
# Out:
# c:\Users\bjm33\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bjm33\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bjm33\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bjm33\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bjm33\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45817 (\N{HANGUL SYLLABLE DANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bjm33\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bjm33\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
